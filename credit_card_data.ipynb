# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('credit_card_messy_final.csv')

# %%
df.head()
# Out:
#     Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0  768805383.0          Blue        150.0                 1.0
# 1  787466808.0          Blue        200.0                 0.0
# 2  718011783.0          Blue        495.0                 1.0
# 3  710540883.0          Blue        330.0                 0.0
# 4  718767183.0          Blue        195.0                 0.0
#
#    Customer_Acq_Cost Week_Start_Date  Week_Num Qtr  current_year  \
# 0               82.0      10-09-2023       NaN  Q3        2023.0
# 1              126.0      22-10-2023       NaN  Q4        2023.0
# 2              118.0      02-07-2023       NaN  Q3        2023.0
# 3              112.0      12-02-2023       NaN  Q1        2023.0
# 4               93.0      16-07-2023       NaN  Q3        2023.0
#
#    Credit_Limit  Total_Revolving_Bal  Total_Trans_Amt  Total_Trans_Vol  \
# 0       12691.0                777.0           1144.0             42.0
# 1        3009.0               2517.0           5329.0             82.0
# 2        2205.0               1337.0           1591.0             38.0
# 3        6590.0                  0.0           2449.0             67.0
# 4        2192.0               1464.0           4905.0             89.0
#
#    Avg_Utilization_Ratio Use Chip Exp Type  Interest_Earned  Delinquent_Acc
# 0                  0.061   Swipe     Bills           320.32             0.0
# 1                  0.836   Swipe      Food           959.22             0.0
# 2                  0.606   Swipe     Bills           350.02             0.0
# 3                  0.000   Swipe     Bills           514.29             0.0
# 4                  0.668   Swipe   Grocery          1422.45             0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10358 entries, 0 to 10357
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Client_Num             10308 non-null  float64
#  1   Card_Category          10003 non-null  object
#  2   Annual_Fees            9791 non-null   float64
#  3   Activation_30_Days     10308 non-null  float64
#  4   Customer_Acq_Cost      9785 non-null   float64
#  5   Week_Start_Date        10308 non-null  object
#  6   Week_Num               0 non-null      float64
#  7   Qtr                    10308 non-null  object
#  8   current_year           10308 non-null  float64
#  9   Credit_Limit           9794 non-null   float64
#  10  Total_Revolving_Bal    10308 non-null  float64
#  11  Total_Trans_Amt        9789 non-null   float64
#  12  Total_Trans_Vol        10308 non-null  float64
#  13  Avg_Utilization_Ratio  9795 non-null   float64
#  14  Use Chip               9992 non-null   object
#  15  Exp Type               10002 non-null  object
#  16  Interest_Earned        9794 non-null   float64
#  17  Delinquent_Acc         10308 non-null  float64
# dtypes: float64(13), object(5)
# memory usage: 1.4+ MB

# %%
df.isnull().sum()
# Out:
# Client_Num                  50
# Card_Category              355
# Annual_Fees                567
# Activation_30_Days          50
# Customer_Acq_Cost          573
# Week_Start_Date             50
# Week_Num                 10358
# Qtr                         50
# current_year                50
# Credit_Limit               564
# Total_Revolving_Bal         50
# Total_Trans_Amt            569
# Total_Trans_Vol             50
# Avg_Utilization_Ratio      563
# Use Chip                   366
# Exp Type                   356
# Interest_Earned            564
# Delinquent_Acc              50
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(249)

# %%
df.dropna(how='all', inplace=True)
df.drop_duplicates(inplace=True)

# %%
for col in df.select_dtypes(include=['int64', 'float64']).columns:
    df[col] = df[col].fillna(df[col].median())

# %%
df.isnull().sum()
# Out:
# Client_Num                   0
# Card_Category              303
# Annual_Fees                  0
# Activation_30_Days           0
# Customer_Acq_Cost            0
# Week_Start_Date              0
# Week_Num                 10108
# Qtr                          0
# current_year                 0
# Credit_Limit                 0
# Total_Revolving_Bal          0
# Total_Trans_Amt              0
# Total_Trans_Vol              0
# Avg_Utilization_Ratio        0
# Use Chip                   303
# Exp Type                   303
# Interest_Earned              0
# Delinquent_Acc               0
# dtype: int64

# %%
for col in df.select_dtypes(include='object').columns:
    df[col]= df[col].fillna(df[col].mode()[0])

# %%
#Data after removing redundant values and null values 
df.shape
# Out:
# (10108, 18)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(10108)
